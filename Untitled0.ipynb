# %% [markdown]
# <a href="https://colab.research.google.com/github/ManoLoeffler/Faculdade-Sistemas-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('teste')

# %%
import gdown

# %%
# !gdown 1exmP2er4MvJ4yyaop3_yGhCYYmGb7s6A

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# AttributeError: 'function' object has no attribute 'head'

# %%
df = pd.read_excel('SuperMercados.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0 ID da fatura Filial Tipo de Cliente Gênero  \
# 0         0.0  750-67-8428      A          Member      F
# 1         1.0  226-31-3081      C          Normal      F
# 2         2.0  631-41-3108      A          Normal      M
# 3         3.0  123-19-1176      A          Member      M
# 4         4.0  373-73-7910      A          Normal      M
#
#          Linha de produto  Preço unitário  Quantidade    Total       Data  \
# 0          Saúde e beleza         1120.35         7.0  7842.45   1/5/2019
# 1  Acessórios eletrônicos          229.20         5.0  1146.00   3/8/2019
# 2   Casa e estilo de vida          694.95         7.0  4864.65   3/3/2019
# 3          Saúde e beleza          873.30         8.0  6986.40  1/27/2019
# 4      Esportes e viagens         1294.65         7.0  9062.55   2/8/2019
#
#       Tempo          Pagamento       COGS  porcentagem de margem bruta  \
# 0  13:08:00                PIX  4705.4700                 4.761905e+09
# ...

# %%
sns.heatmap(df.isnull(),
            yticklabels = False,
            cbar = False,
            cmap = 'gnuplot')
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      Unnamed: 0 ID da fatura Filial Tipo de Cliente Gênero  \
# 0           0.0  750-67-8428      A          Member      F
# 1           1.0  226-31-3081      C          Normal      F
# 2           2.0  631-41-3108      A          Normal      M
# 3           3.0  123-19-1176      A          Member      M
# 4           4.0  373-73-7910      A          Normal      M
# ..          ...          ...    ...             ...    ...
# 995       995.0  233-67-5758      C          Normal      M
# 996       996.0  303-96-2227      B          Normal      F
# 997       997.0  727-02-1313      A          Member      M
# 998       998.0  347-56-2442      A          Normal      M
# 999       999.0  849-09-3807      A          Member      F
#
#            Linha de produto  Preço unitário  Quantidade     Total       Data  \
# 0            Saúde e beleza         1120.35         7.0   7842.45   1/5/2019
# 1    Acessórios eletrônicos          229.20         5.0   1146.00   3/8/2019
# ...

# %%
pip install pyautogui
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 KB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 KB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-061c78f3dd69> in <module>
# ----> 1 plt.style.use('Classic')
#
# NameError: name 'plt' is not defined
